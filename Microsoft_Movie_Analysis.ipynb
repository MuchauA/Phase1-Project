# %% [markdown]
# **MICROSOFT MOVIE ANALYSIS_PROJECT**

# %% [markdown]
# ## ***Loading DataSets to google.colab***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files #importing files to google_colab
uploaded = files.upload() #uploading the imported files
# Out:
#      <input type="file" id="files-b67a23e5-cc59-4bbd-a9cf-262e8e2b484b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b67a23e5-cc59-4bbd-a9cf-262e8e2b484b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imdb.title.basics.csv.gz to imdb.title.basics.csv.gz

# %%
import csv
import pandas as pd
df_title = pd.read_csv('imdb.title.basics.csv.gz')
df_title
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d20454e-264e-4a68-936a-226e4871156f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d20454e-264e-4a68-936a-226e4871156f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bom.movie_gross.csv.gz to bom.movie_gross.csv.gz

# %%
import csv
df_gross =pd.read_csv('bom.movie_gross.csv.gz')
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4eca507d-28a0-4528-b68f-4908298c6d6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4eca507d-28a0-4528-b68f-4908298c6d6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tmdb.movies.csv.gz to tmdb.movies.csv.gz

# %%
import csv
df_movies = pd.read_csv("tmdb.movies.csv.gz")
df_movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %% [markdown]
# #DATA CLEANING

# %% [markdown]
# **Performing Data Cleaning on the loaded Data_sets**

# %% [markdown]
# **1. Data cleaning the Title DataSet**

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df_title.shape
# Out:
# (146144, 6)

# %%
df_title.isna().sum() #check for missing values in the imdb.title.basics dataset
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %% [markdown]
# ### Interpreting the above results: runtime_minutes column has the highest number of empty/null values. As a result,we drop the column.

# %%
df_title.drop("runtime_minutes", axis = 1, inplace = True)
df_title
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# ##find the unique values in genres column

# %%
df_title['genres'].unique() #checking for unique values in the genres column of the title.basics dataset
# Out:
# array(['Action,Crime,Drama', 'Biography,Drama', 'Drama', ...,
#        'Music,Musical,Reality-TV', 'Animation,Crime',
#        'Adventure,History,War'], dtype=object)

# %%
df_title['genres'].value_counts()
# Out:
# Documentary                   32185
# Drama                         21486
# Comedy                         9177
# Horror                         4372
# Comedy,Drama                   3519
#                               ...
# Adventure,Music,Mystery           1
# Documentary,Horror,Romance        1
# Sport,Thriller                    1
# Comedy,Sport,Western              1
# Adventure,History,War             1
# Name: genres, Length: 1085, dtype: int64

# %%
df_title.duplicated() #check for the total number of duplicates in the title.basics dataset
print(len(df_title.duplicated()))
# Out:
# 146144

# %%
df_title.drop_duplicates(subset = 'genres') #drop duplicates in the genres column of the title.basics dataset
# Out:
#            tconst                    primary_title  \
# 0       tt0063540                        Sunghursh
# 1       tt0066787  One Day Before the Rainy Season
# 2       tt0069049       The Other Side of the Wind
# 3       tt0069204                  Sabse Bada Sukh
# 4       tt0100275         The Wandering Soap Opera
# ...           ...                              ...
# 141789  tt9283064              Vancouver Remembers
# 141816  tt9287494                          Display
# 141948  tt9310166  The Original Santa Claus Parade
# 141973  tt9314086                  Deadly Business
# 146138  tt9916428              The Secret of China
#
#                          original_title  start_year  \
# 0                             Sunghursh        2013
# 1                       Ashad Ka Ek Din        2019
# 2            The Other Side of the Wind        2018
# 3                       Sabse Bada Sukh        2018
# 4                 La Telenovela Errante        2017
# ...

# %%
df_title['genres'].nunique() #check fortotal number of unique values in the genres column of the title.basics dataset
# Out:
# 1086

# %% [markdown]
# *from the information above,genres column has 5408 null values. Instead of dropping the entire column, we can keep the column but replace the NaN values with "Missing"*.

# %%
df_title['genres'] = df_title['genres'].fillna("Missing")
df_title
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df_title.isna().sum() #assert there are no missing values in the genres column
# Out:
# tconst             0
# primary_title      0
# original_title    21
# start_year         0
# genres             0
# dtype: int64

# %% [markdown]
# *For the original_title column which has 21 missing values,we replace NaN with "Missing"*

# %%
df_title['original_title'] = df_title['original_title'].fillna("Missing")
df_title
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df_title.isna().sum()
# Out:
# tconst            0
# primary_title     0
# original_title    0
# start_year        0
# genres            0
# dtype: int64

# %% [markdown]
# **2. Performing data cleaning on bom.movie_gross DataSet**

# %%
df_gross.isna().sum() #checking for the total missing values in the bom_movie_gross dataset
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# *Check the datatypeof each column*

# %%
df_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df_gross['foreign_gross'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ***convert the DataType of the column "foreign_gross" from object type to float***

# %%
df_gross['foreign_gross'] = pd.to_numeric(df_gross['foreign_gross'], errors = 'coerce')
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %% [markdown]
# **assert the dtype has changed***

# %%
df_gross['foreign_gross'].dtype
# Out:
# dtype('float64')

# %%
df_gross.isna().sum() #look for missing values remaining in the movie_gross dataset
# Out:
# title              0
# studio             5
# domestic_gross    28
# foreign_gross      0
# year               0
# dtype: int64

# %% [markdown]
# *From the bom.movie_gross, the foreign_gross column has 1350 null values. Since the values are numerical, we replace the missing values with the column median*

# %%
df_gross['foreign_gross'] = df_gross['foreign_gross'].fillna(df_gross['foreign_gross'].median())
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
df_gross.isna().sum() #check for total null values, per column,  in the movie_gross dataset
# Out:
# title              0
# studio             5
# domestic_gross    28
# foreign_gross      0
# year               0
# dtype: int64

# %%
df_gross['domestic_gross'].dtype #finding the datatype of the domestic_gross column
# Out:
# dtype('float64')

# %% [markdown]
# *domestic_gross column has 28 missing values. We replace the missing values with the median*

# %%
df_gross['domestic_gross'] = df_gross['domestic_gross'].fillna(df_gross['domestic_gross'].median())
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
df_gross['domestic_gross'].median() #finding the median of the domestic_gross column
# Out:
# 1400000.0

# %% [markdown]
# *ascertain there are no null values in domestic_gross column*

# %%
df_gross['domestic_gross'].isna().sum()
# Out:
# 0

# %% [markdown]
# *Studio column has 5 null values,we replace them with the most common value in the column*

# %%
df_gross['studio'].value_counts() #check for the total number of values for each unique entry in the studio column of bom.movie_gross dataset
# Out:
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 257, dtype: int64

# %% [markdown]
# *The most common value in studio column is IFC, hence, we replace the null values with IFC*

# %%
df_gross['studio'] = df_gross['studio'].fillna('IFC')
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %% [markdown]
# Assert the values are filled and there are no missing values in the dataset

# %%
df_gross.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %% [markdown]
# **3. Data cleaning in tmdb.movies DataSet**

# %%
df_movies #load the tmdb.movies Dataset
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df_movies.shape
# Out:
# (26517, 10)

# %% [markdown]
# *check for duplicates in the movies dataset*

# %%
df_movies.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *check for null/empty values *

# %%
df_movies.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %% [markdown]
# **The tmdb_movies dataset has 26517 rows and 10 columns. There are no missing values in the dataset**

# %% [markdown]
# #DATA VISUALIZATION

# %%
x = df_title.groupby('genres').sum()
x
# Out:
#                             start_year
# genres
# Action                         4471358
# Action,Adult,Comedy               4028
# Action,Adventure                229721
# Action,Adventure,Animation      396974
# Action,Adventure,Biography       68516
# ...                                ...
# Thriller,War,Western              2016
# Thriller,Western                  8053
# War                             263930
# War,Western                       2014
# Western                         286198
#
# [1086 rows x 1 columns]

# %%
df_title['genres'].value_counts()
# Out:
# Documentary                   32185
# Drama                         21486
# Comedy                         9177
# Missing                        5408
# Horror                         4372
#                               ...
# Adventure,Music,Mystery           1
# Documentary,Horror,Romance        1
# Sport,Thriller                    1
# Comedy,Sport,Western              1
# Adventure,History,War             1
# Name: genres, Length: 1086, dtype: int64

# %% [markdown]
# *Plotting a bar graph for the most popular movie genres. i.e: Documentary, Drama, Comedy, Horror *

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Most popular Movie Genres")
plt.xlabel("Genres")
plt.ylabel("Value Counts")
x = np.array( ['Documentary', 'Drama', 'Comedy','Horror'])
y = np.array([32185, 21486, 9177, 4372])
plt.bar(x, y, color = "blue")
plt.show()

# %% [markdown]
# *The above graph shows the 4 top most popular movies genres. The most popular movie genre is the documentary*

# %% [markdown]
# Find the correlation between the vote_count and popularity in the movies dataset

# %%
corr = df_movies['vote_count'].corr(df_movies['popularity'])
corr
# Out:
# 0.6948493710333694

# %%
import seaborn as sns

sns.regplot(x=df_movies["vote_count"], y=df_movies["popularity"])
plt.savefig("Plotting_Correlation.jpg")

# %% [markdown]
# There is a  moderate positive relationship between popularity and vote_count. This means that if a movie is popular, there's a likelyhood that it will be voted for
